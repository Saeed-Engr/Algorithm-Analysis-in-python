# %% [markdown]
# # Linear Search Algorithm

# %% [markdown]
# - Linear search is a sequential searching algorithm where we start from one end and check every element of the list until the desired element is found. It is the simplest searching algorithm.

# %% [markdown]
# # Working of Linear Search

# %% [markdown]
# - The following steps are followed to search for an element k = 1 in the list below.

# %% [markdown]
# ![l1.jpg](attachment:l1.jpg)

# %% [markdown]
# - Start from the first element, compare k with each element x.

# %% [markdown]
# ![l2.jpg](attachment:l2.jpg)

# %% [markdown]
# - If x == k, return the index.

# %% [markdown]
# ![l3.jpg](attachment:l3.jpg)

# %% [markdown]
# - Else, return not found.

# %% [markdown]
# # Algoritm of Linear Search

# %% [raw]
# LinearSearch(array, key)
#   for each item in the array
#     if item == value
#       return its index

# %% [markdown]
# # Linear Search Code in python

# %%
#ceating function

def LinearSearch(list, length, key):
    
# Going through array sequencially
    for i in range(0, length):
        if (list[i] == key):
            return i
    return -1
    
    


list = [2,3,6,1,9,10,20,5,70,30,15,95,33,100]
key = 100
length = len(list)
result = LinearSearch(list,length, key )
if(result == -1):
    print("Element not found")
else:
    print("Element found at index: ", result)
# Out:
# Element found at index:  13
